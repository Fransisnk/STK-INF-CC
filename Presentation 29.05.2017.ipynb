# %%
import linearRegression
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
import pandas as pd
import dataframes
from sklearn.neural_network import MLPClassifier
from datetime import timedelta, datetime, date
import matplotlib as mpl
from sklearn.externals import joblib
mpl.rcParams['figure.figsize'] = 16, 10

# %%
training = linearRegression.Training()
data = training.fetchData()
dataframe = training.readAndPrepareData(data, trainingDays=365, testDays=7)
# Out:
# complete data size: 15664
# length of cut data: 4093
# Coefficients:
#  [ -3.03394192e+14  -3.03394192e+14  -3.03394192e+14  -3.03394192e+14
#   -3.03394192e+14  -3.03394192e+14  -3.03394192e+14  -3.03394192e+14
#   -3.03394192e+14  -3.03394192e+14  -3.03394192e+14  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13  -3.26584936e+13  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13  -3.26584936e+13  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13  -3.26584936e+13  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13  -3.26584936e+13  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13  -3.26584936e+13  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13  -3.26584936e+13  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13  -3.26584936e+13  -3.26584936e+13
#   -3.26584936e+13  -3.26584936e+13   1.32469582e+14   1.32469582e+14
#    1.32469582e+14   1.32469582e+14   1.32469582e+14   1.32469582e+14
#    1.32469582e+14  -2.19720391e+15  -2.19720391e+15  -2.19720391e+15
#    9.28616163e+14   9.28616163e+14   9.28616163e+14  -3.76056157e+14
#   -3.76056157e+14  -3.76056157e+14  -4.94949241e+14  -4.94949241e+14
#   -4.94949241e+14   2.46023015e+15  -6.65589926e+14   6.39082395e+14
#    7.57975478e+14  -9.17761001e-16  -1.05891218e-15  -2.25593506e+14
#   -2.25593506e+14]
# LinReg mean squared error: 1324.71
# MLP mean squared error:  2824.85897436
# Variance score LinReg: 0.88
# mean hit rate 25%:  0.6923076923076923

# %%
training.plotMLPandLinReg(dataframe)

# %%
training.plotDeviations(dataframe)
